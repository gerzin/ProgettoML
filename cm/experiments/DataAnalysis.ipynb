# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn')
params = {
    'figure.figsize': (20, 15),
    'legend.fontsize': 'x-large',
    'axes.labelsize': 'x-large',
    'axes.titlesize':'x-large',
    'xtick.labelsize':'x-large',
    'ytick.labelsize':'x-large',
    'axes.titlesize': 'x-large',
}
plt.rcParams.update(params)

# %%
import pathlib
DATASET_PATH = pathlib.Path(pathlib.Path.cwd()).parent / "data"
DATASET_NAME = "ML-CUP19-TR.csv"
print(DATASET_PATH / DATASET_NAME)
# Out:
# /Users/gerardozinno/repos/ProgettoML/cm/data/ML-CUP19-TR.csv

# %%
df = pd.read_csv(DATASET_PATH / DATASET_NAME, sep=',', comment='#', skiprows=7, header=None, index_col=0)

# %%
df
# Out:
#             1         2         3         4         5         6         7   \
# 0
# 1     0.403680 -1.263305 -1.405777 -1.204391 -1.150933 -0.015976  1.050295
# 2    -0.985474  1.495285 -0.947413  0.520832  0.116691 -1.118318 -1.221874
# 3    -0.985464  1.270111 -1.864167  1.234743  1.595580 -1.187201 -1.162063
# 4     0.908829 -0.756618 -0.214001 -0.490480 -1.643876  0.810767  0.272982
# 5    -0.543471  0.481930 -0.305679 -0.252544  0.891350  0.466289 -1.281666
# ...        ...       ...       ...       ...       ...       ...       ...
# 1761  0.466818  0.538237  1.069432  0.996778  1.313897  0.466274  0.631742
# 1762  1.224542 -0.925509 -0.489039 -1.620840 -1.291793  0.604076  0.930718
# 1763 -0.859179  1.101226 -1.497439 -0.133560  0.327970 -0.842710 -1.042475
# 1764 -1.427481  1.213816 -1.497467  1.353714  1.102624 -1.324974 -1.401257
# 1765  0.593113 -0.587730  0.244367 -0.549979 -1.080514  0.879627  0.153403
#
# ...

# %%
target_points = df[df.columns[-2:]]

# %%
target_points.columns = ['X', 'Y']
target_points
# Out:
#               X          Y
# 0
# 1      4.130912  -0.288271
# 2     29.499045  -4.535635
# 3     24.145767  -9.474121
# 4     12.543412  -9.214210
# 5     19.650184 -13.604542
# ...         ...        ...
# 1761  17.107064 -14.230131
# 1762   7.439563  -3.841417
# 1763  30.174705  -3.896773
# 1764  26.407248  -7.409214
# 1765  14.359992 -11.188382
#
# [1765 rows x 2 columns]

# %%
feature_points = df[df.columns[:-2]]

# %%
feature_points.columns = [str(i+1) for i in range(len(feature_points.columns))]

# %%
feature_points
# Out:
#              1         2         3         4         5         6         7  \
# 0
# 1     0.403680 -1.263305 -1.405777 -1.204391 -1.150933 -0.015976  1.050295
# 2    -0.985474  1.495285 -0.947413  0.520832  0.116691 -1.118318 -1.221874
# 3    -0.985464  1.270111 -1.864167  1.234743  1.595580 -1.187201 -1.162063
# 4     0.908829 -0.756618 -0.214001 -0.490480 -1.643876  0.810767  0.272982
# 5    -0.543471  0.481930 -0.305679 -0.252544  0.891350  0.466289 -1.281666
# ...        ...       ...       ...       ...       ...       ...       ...
# 1761  0.466818  0.538237  1.069432  0.996778  1.313897  0.466274  0.631742
# 1762  1.224542 -0.925509 -0.489039 -1.620840 -1.291793  0.604076  0.930718
# 1763 -0.859179  1.101226 -1.497439 -0.133560  0.327970 -0.842710 -1.042475
# 1764 -1.427481  1.213816 -1.497467  1.353714  1.102624 -1.324974 -1.401257
# 1765  0.593113 -0.587730  0.244367 -0.549979 -1.080514  0.879627  0.153403
#
# ...

# %%
target_points.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1765 entries, 1 to 1765
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       1765 non-null   float64
#  1   Y       1765 non-null   float64
# dtypes: float64(2)
# memory usage: 41.4 KB

# %%
feature_points.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1765 entries, 1 to 1765
# Data columns (total 20 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   1       1765 non-null   float64
#  1   2       1765 non-null   float64
#  2   3       1765 non-null   float64
#  3   4       1765 non-null   float64
#  4   5       1765 non-null   float64
#  5   6       1765 non-null   float64
#  6   7       1765 non-null   float64
#  7   8       1765 non-null   float64
#  8   9       1765 non-null   float64
#  9   10      1765 non-null   float64
#  10  11      1765 non-null   float64
#  11  12      1765 non-null   float64
#  12  13      1765 non-null   float64
#  13  14      1765 non-null   float64
#  14  15      1765 non-null   float64
#  15  16      1765 non-null   float64
#  16  17      1765 non-null   float64
#  17  18      1765 non-null   float64
#  18  19      1765 non-null   float64
#  19  20      1765 non-null   float64
# dtypes: float64(20)
# ...

# %%
tmp = target_points.apply(lambda x : x > 0)
print(tmp['X'].value_counts(), "\n")
print(tmp['Y'].value_counts())
# Out:
# True    1765
# Name: X, dtype: int64
#
# False    1737
# True       28
# Name: Y, dtype: int64

# %%
target_points.describe()
# Out:
#                  X            Y
# count  1765.000000  1765.000000
# mean     17.168133    -8.096322
# std       8.073958     4.211957
# min       3.327223   -14.924220
# 25%      10.102304   -11.668957
# 50%      16.975651    -8.340907
# 75%      24.189793    -4.665968
# max      31.626813     0.597136

# %%
target_points.hist()
# Out:
# array([[<AxesSubplot:title={'center':'X'}>,
#         <AxesSubplot:title={'center':'Y'}>]], dtype=object)

# %%
feature_points.describe()
# Out:
#                  1            2            3            4            5  \
# count  1765.000000  1765.000000  1765.000000  1765.000000  1765.000000
# mean     -0.033852    -0.003344    -0.728060     0.027490    -0.034446
# std       1.009759     0.986107     0.783082     1.012350     1.052468
# min      -1.869478    -1.657403    -3.239290    -1.858795    -2.207303
# 25%      -1.048613    -0.925522    -1.222428    -0.906943    -1.010087
# 50%       0.214247    -0.024736    -0.672381     0.104407     0.116697
# 75%       0.845674     0.876025    -0.214026     0.937282     0.820912
# max       1.666555     1.889392     1.436124     2.067618     2.088571
#
#                  6            7            8            9           10  \
# count  1765.000000  1765.000000  1765.000000  1765.000000  1765.000000
# mean      0.050069     0.003721    -0.013258    -0.033852    -0.034446
# std       0.984558     0.995662     0.993279     1.009759     1.052468
# ...

# %%
feature_points.hist()
# Out:
# array([[<AxesSubplot:title={'center':'1'}>,
#         <AxesSubplot:title={'center':'2'}>,
#         <AxesSubplot:title={'center':'3'}>,
#         <AxesSubplot:title={'center':'4'}>],
#        [<AxesSubplot:title={'center':'5'}>,
#         <AxesSubplot:title={'center':'6'}>,
#         <AxesSubplot:title={'center':'7'}>,
#         <AxesSubplot:title={'center':'8'}>],
#        [<AxesSubplot:title={'center':'9'}>,
#         <AxesSubplot:title={'center':'10'}>,
#         <AxesSubplot:title={'center':'11'}>,
#         <AxesSubplot:title={'center':'12'}>],
#        [<AxesSubplot:title={'center':'13'}>,
#         <AxesSubplot:title={'center':'14'}>,
#         <AxesSubplot:title={'center':'15'}>,
#         <AxesSubplot:title={'center':'16'}>],
#        [<AxesSubplot:title={'center':'17'}>,
#         <AxesSubplot:title={'center':'18'}>,
#         <AxesSubplot:title={'center':'19'}>,
#         <AxesSubplot:title={'center':'20'}>]], dtype=object)

# %%
corrMatrix = feature_points.corr()
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %%
feature_points['12']
# Out:
# 0
# 1      -0.500363
# 2      -0.971660
# 3      -1.065927
# 4       0.630728
# 5       0.347945
#           ...
# 1761    0.724981
# 1762    0.159437
# 1763   -1.254447
# 1764   -2.762563
# 1765    0.159442
# Name: 12, Length: 1765, dtype: float64

# %%
feature_points['13']
# Out:
# 0
# 1      -0.500365
# 2      -0.971675
# 3      -1.065933
# 4       0.630722
# 5       0.347952
#           ...
# 1761    0.724969
# 1762    0.159423
# 1763   -1.254447
# 1764   -2.762544
# 1765    0.159439
# Name: 13, Length: 1765, dtype: float64

# %%
m = (feature_points['12'] - feature_points['13']).apply(lambda x : abs(x) < 1e-4)

# %%
all(m)
# Out:
# True
